# %%
import matplotlib.pyplot as plt
import numpy as np

def plotExample(xs, ys, points=[]):
    for (x, y) in points:
        plt.plot(x, y, marker='D')
        plt.text(x, y, f'({x}, {y})')

    plt.plot(xs, ys, linestyle='--')
    plt.axhline(y=0, color='k')
    plt.axvline(x=0, color='k')
    plt.axis('scaled')
    plt.show()

# %% [markdown]
# # Matemática - Ciência e Aplicações vol. 1 (9a Edição)

# %% [markdown]
# # 1 - Noções de Conjuntos
#
# A noção básica de conjunto não é definida, é uma *noção primitiva*.
#
# Representação:
# - **conjunto**: geralmente letra maiúscula (ex: A, B, C)
# - **elemento**: geralmente letra minúsucula (ex: a, b, c)
# - **pertinência**: $A = \{ a, b, c \};  b \in A$
# - **igualdade**: $A = B$ se $(x \in B, \forall x \in A)$ e $(x \in A, \forall x \in B)$;
# - **conjunto vazio**: $\emptyset$ ou $\{ \}$
#
# - $A \subset B$: "está contido em". $A$ é um subconjunto de $B$, $B$ possui todos elementos pertencentes a $A$
# - $B \supset A$: B contém A
#
# Propriedades da relação de inclusão:
# - **Reflexiva**: $A \subset A$
# - **Transitiva**: se $A \subset B$ e $B \subset C$, então $A \subset C$
# - **Antissimétrica**: se $A \subset B$ e $B \subset A$, então $A = B$
#
#
# **Conjunto das partes**: $P(A)$, conjunto que contém todos possíveis subconjuntos de A. Exemplo: $$A = \{ a, b \}; P(A) = \{ \emptyset, \{ a \}, \{ b \}, \{ a, b \} \}$$
#
#
# **Interseção:** $A \cap B = \{ x   \vert   x \in A$ **e** $x \in B \}$
#
# **União:** $A \cup B = \{ x   \vert   x \in A$ **ou** $x \in B \}$
#
# "e" pode ser substituído pelo símbolo $\land$; "ou" pode ser substituído por $\lor$
#
# **Conjunto Universo**: Conjunto de todos elementos possíveis: $U$
#
# **Número de elementos**: $n(A \cup B) = n(A) + n(B) - n(A \cap B)$
#
# Propriedades união/interseção:
# - **Indepotente**: $A \cap A = A$ e $A \cup A = A$
# - **Comutativa**: $A \cap B = B \cap A$ e $A \cup B = B \cup A$
# - **Associativa**: $A \cap (B \cap C) = (A \cap B) \cap C$ (mesma coisa pra $\cup$)
# - **Distributiva**: $A \cap (B \cup C) = (A \cap B) \cup (A \cap C)$  e  $A \cup (B \cap C) = (A \cup B) \cap (A \cup C)$
#
# **Diferença**: $A - B = \{x | x \in A \land x \notin B \}$
#
#
# **Conjunto complementar**: Quando $A \supset B$, $A-B$ é chamado **complementar de B em relação a A** ou $\complement^B_A$
#
#
# $\complement^A_U$ (complementar de A em relação ao universo) é escrito como $\overline{A}$
#
# ---

# %% [markdown]
# # 2 - Conjuntos Numéricos
#
# ## Números Naturais
#
# $\mathbb{N} = \{ 0, 1, 2, 3, 4, ... \}$
#
# - $\mathbb{N}^* = \{ 1, 2, 3, 4, ... \}$ (inteiros não nulos)
# - $\mathbb{N}_p$: inteiros pares, $\mathbb{N}_i$ inteiros ímpares
#
# $\mathbb{N}$ é fechado em relação à adição e multiplicação ($\forall n \in \mathbb{N}$ e $m \in \mathbb{N}$,&nbsp;&nbsp; $m + n \in \mathbb{N}$ &nbsp;&nbsp;  e &nbsp;&nbsp;    $n \cdot m \in \mathbb{N}$)
#
# ---
#
# ## Número Inteiros
#
# $\mathbb{Z} = \{ -1, -2, -3, 0, 1, 2, 3, 4, ... \}$
#
# - $\mathbb{Z}^*$: Inteiros não nulos
# - $\mathbb{Z}_+$, $\mathbb{Z}_-$:: Inteiros não negativos, inteiros não positivos
# - $\mathbb{Z}^*_+$: inteiros positivos
#
# $-a$ é o **oposto** de $a$ (e vice-versa)
#
# $\mathbb{Z}$ é fechado em relação à adição, multiplicação e subtração
#
# ---
#
# ## Números racionais
#
# $\mathbb{Q} = \{ \frac{p}{q} $ &nbsp; $|$ &nbsp; $p \in \mathbb{Z}$ &nbsp; e &nbsp; $q \in \mathbb{Z}^* \}$
#
# p é o **numerador**,  q é o **denominador**.
#
# $\mathbb{Q}$ é fechado para adição, multiplicação e subtração.
#
# Como não se define divisão por 0, $\mathbb{Q}^*$ é fechado em relação à divisão.
#
# ### Dízimas períodicas:
#
# Ocorre repetições de algarismos: $0,666...$ ( $0,\overline{6}$ ), &nbsp; &nbsp; $0.121212...$ ( $0,\overline{12}$ )
#
# A fração que gera uma dízima é chamada **geratriz**.
#
# Uma fração **irredutível** gera uma dízima somente se na decomposição do denominador em fatores primos haja  um fator diferente de 2 e 5.
#
# Dois números $m$ e $n$ são **inversos** se $m \cdot n = 1$ (ex: $2$ e $\frac{1}{2}$, &nbsp; $\frac{5}{6}$ e $\frac{6}{5}$)
#
# ---
#
# ## Números Irracionais
#
# Conjunto $\mathbb{I}$: dízimas não períodicas, não podem ser escritos como frações com numerador e denominador inteiros. (exs: $\sqrt{2}$, $\pi$)
#
# ### Demonstração que $\sqrt{2}$ é irracional:
#
# Suponha que $\sqrt{2}$ é racional, então:
#
# $\sqrt{2} = \frac{p}{q}$ &nbsp; &nbsp; (onde $\frac{p}{q}$ é uma fração irredutível, $mdc(p, q) = 1$)
#
# &nbsp; &nbsp; $\Rightarrow$ &nbsp; &nbsp;  $2 = \frac{p^2}{q^2}$ &nbsp; &nbsp; $\Rightarrow$ &nbsp; &nbsp; $2 \cdot q^2 = p^2$
#
# Onde conclui-se, que p é par.
#
# &nbsp; &nbsp; $\Rightarrow$ &nbsp; &nbsp;  $2 \cdot q^2 = (2k)^2$ &nbsp; &nbsp; $\Rightarrow$ &nbsp; &nbsp; $2 \cdot q^2 = 4k^2$ &nbsp; &nbsp; $\Rightarrow$ &nbsp; &nbsp; $2 \cdot q^2 = 2 \cdot 2k^2$ &nbsp; &nbsp; $\Rightarrow$ &nbsp; &nbsp; $q = 2k$
#
# On também conclui-se que q é par, o que é um absurdo, pois p e q não podem ser pares se $\frac{p}{q}$ é irredutível.
#
#  &nbsp; &nbsp; $\therefore$ &nbsp; $\sqrt{2}$ é irracional.
#
# ---
#
# ## Números Reais
#
# $\mathbb{R} = \mathbb{Q} \cup \mathbb{I}$
#
# ### Intervalos Reais:
#
# $[3, 5[$ &nbsp; $= \{ x \in \mathbb{R}$ &nbsp; $|$ &nbsp; $x \geq 3$ &nbsp; e &nbsp; $x \lt 5 \}$
#
# ![intervalo](img/intervalo.jpg)
#
# Bolinha fechada: inclui, bolinha aberta: não inclui.
#
# ### Razão
#
# $\frac{a}{b}$ &nbsp; ou &nbsp; $a : b$ &nbsp; com $b \neq 0$ é chamada de **razão** ou **quociente**. $a$ é o **antecedente**, $b$ é o **consequente**.
#
# ### Proporção
#
# $\frac{a}{b} = \frac{c}{d}$
#
# $a$ e $d$ são chamados **extremos**, $b$ e $c$ **meios**. $a \cdot d = b \cdot c$ (produto dos extremos é igual ao dos meios).
#
# **Porcentagem**: razão de denominador (consequente) 100.
#
# ---

# %% [markdown]
# # 3 - Funções
#
# **Função**: Relação entre 2 conjuntos $A$ e $B$ que associa a cada elemento $x \in A$ um único elemento $y \in B$.
#
# Pode ser escrita por um conjunto de pares ordenados, definida por fórmulas, escrita em forma de tabela, etc.
#
# Notação: $y \in B$ é a **imagem** de $f$. &nbsp; &nbsp; Escrevemos $y = f(x)$
#
# Em uma função $f: A \rightarrow B$, &nbsp; &nbsp; &nbsp; $A$ é o **domínio**, $B$ o **contradomínio** de $f$.
#
# ### Determinação do domínio:
#
# O domínio de $f(x) = \frac{x + 3}{x - 1}$ &nbsp; é &nbsp; $\mathbb{R} - \{ 1 \}$ (denominador não pode ser 0)
#
# O domínio de $f(x) = \sqrt(x - 2)$ &nbsp;&nbsp; é &nbsp; $\{ x \in \mathbb{R}$ &nbsp; $|$ &nbsp; $x \geq 2 \}$ (raizes de números negativos não pertecem a $\mathbb{R}$.
#
# ---
#
# Uma função é **crescente** (num intervalo) se $f(a) > f(b)$ &nbsp; $\forall a > b$ (naquele intervalo). O **valor mínimo** é o menor valor de $f(x)$ (num intervalo). Se $f(x) >= f(x_0)$ para todo $x$ (num intervalo), o **ponto mínimo** é $(x_0, f(x_0))$.
#
# Similarmente, temos o conceito de função **decrescente**, **valor máximo** e **ponto máximo**.
#
# ---
#
# Representação no plano cartesiano: $x$ no eixo horizontal (**abscissas**), $f(x)$ ou $y$ no vertical (eixo das **ordenadas**).
#
# ---
#
# **Quadrantes**: o primeiro quadrante é onde $x > 0$ e $y > 0$, contamos os demais no sentido anti-horário.
#
# | Qd 4  | Qd 1  |
# | :---: | :---: |
# | Qd 3  | Qd 2  |
#
#
# ---
#
# O valor de $x$ que anula $f(x)$ é chamado **raiz** ou **zero** da função.
#
# Estudo do sinal: determinar para quais valores de $x$ tem-se $y > 0$ e para quais tem-se $y < 0$.
#
# Exemplo:
#
# ![função](img/funcao1.jpg)
#
# Estudo do sinal:
#
# $y < 0$ se: &nbsp; &nbsp; $x < a$ &nbsp; ou &nbsp; $b < x < c$ &nbsp; ou &nbsp; $d < x < e$
#
# $y > 0$ se: &nbsp; &nbsp; $a < x < b$ &nbsp; ou &nbsp; $c < x < d$ &nbsp; ou &nbsp; $x > e$
#
# ---
#
# Se $f(x) = f(-x)$ &nbsp; &nbsp; $\forall x \in D$, então $f$ possui um **gráfico simétrico em relação ao eixo $y$** e temos uma **função par**. (ex: parábola)
#
# Se $f(x) = -f(x)$ &nbsp; &nbsp; $\forall x \in D$, então $f$ possui um **gráfico simétrico em relação a origem** e temos uma **função ímpar**. (ex: $y = ax$)
#
# ---
#
# **Taxa média de variação num intervalo $[x_0, x_1]$**: $\frac{f(x_1)-f(x_0)}{x_1-x_0}$
#
# ---

# %% [markdown]
# # 4 - Função Afim
#
# Função polinomial do 1o grau.
#
# Qualquer função f de $\mathbb{R}$ em $\mathbb{R}$ cuja lei tem o formato *$f(x) = a \cdot x + b$* &nbsp; &nbsp; ($a, b \in \mathbb{R}$, &nbsp; $a \neq 0$)
#
# *a*: **coeficiente**
#
# *b*: termo **constante** ou **independente**
#
# ---
#
# **Funções Lineares**: $b = 0$. Gráfico: reta oblíqua (não paralela) aos eixos Ox e Oy, cruzando a origem.
#
# **Funções Constantes**: $a = 0$. Gráfico: reta paralela ao eixo Ox.
#
# ---
#
# **Grandezas Diretamente Proporcionais**: Grandezas onde $\frac{x}{y} = k$, para k constante. (Relação entre as duas é uma função linear)
#
# ---
#
# **Raíz**: $f(x) = 0 \Rightarrow a \cdot x + b = 0 \Rightarrow x = \frac{-b}{a}$
#
# ---
#
# **Taxa de variação**: Igual ao coeficiente $a$ (p/ qualquer intervalo).
#
# Para $a > 0$ a função é **crescente**.
#
# Para $a < 0$ a função é **descrescente**.
#
# ---
#
# a também é chamado de **coeficiente ângular**, b de **coeficiente linear** (ordenada do ponto onde a reta intersecta o eixo Oy).
#
# ---
#
# ### Estudo do Sinal
#
# Determinar a raiz $r = \frac{-b}{a}$
#
# Se é $f(x)$ é crescente: $y > 0$ &nbsp; para $x > r$ &nbsp; &nbsp e &nbsp; &nbsp; $x < 0$ &nbsp; para $x < r$
#
# Se é $f(x)$ é decrescente: $y > 0$ &nbsp; para $x < r$ &nbsp; &nbsp e &nbsp; &nbsp; $x > 0$ &nbsp; para $x < r$
#
# ---
#
# Inequações: lembrar que o sinal da desigualdade inverte quando multiplicado por negativo.
#
# Ex: $-3x \leq -12 \Rightarrow 3x \geq 12$
#
# ---
#
# Grandezas inversamente proporcionais: $x \cdot y = k$
#
# ---
#
# ### Exemplo
#
# Para $f(x) = -2x + 3$:
#
# - $a < 0$, reta decrescente
#
#
# - Intersecção com y: $f(0) = -2\cdot0 +3 = 3$ &nbsp; $\Rightarrow$ &nbsp; $(0, 3)$
#
#
# - Raíz: $-2x + 3 = 0$ &nbsp; $\Rightarrow$ &nbsp; $-2x = -3$ &nbsp; $\Rightarrow$ &nbsp; $x = \frac{3}{2}$ &nbsp; $\Rightarrow$ &nbsp; $(\frac{3}{2}, 0)$

# %%
xs = np.linspace(-4, 4)
ys = -2*xs + 3
points = [(0, 3), ((3/2), 0)]

plotExample(xs, ys, points)

# %% [markdown]
# # 5 - Função Quadrática
#
# Função poliinomial do 2o grau.
#
# $f(x) = a \cdot x^2 + b \cdot x + c$ &nbsp; &nbsp; onde a, b, c são reais e $a \neq 0$
#
# Gráfico no formato de parábola.
#
# ---
#
# ### Raízes
#
# $\Delta = b^2 - 4ac$
#
# $x = \frac{-b \pm \sqrt{\Delta}}{2a}$
#
# ---
#
# $\Delta = 0$ uma raiz (vértice)
#
# $\Delta > 0$ duas raízes
#
# $\Delta < 0$ não possui raízes reais (parábola não intersecta Ox)
#
# ---
#
# $x_1 + x_2 = \frac{-b}{a}$
#
# $x_1 \cdot x_2 = \frac{c}{a}$
#
# ---
#
# ### Forma Fatorada
#
# Isola-se a: $f(x) = a \cdot ( x^2 + \frac{b}{a} \cdot x + \frac{c}{a} )$
#
# Sabendo-se as raízes, pode-se escrever: $f(x) = (x - x_1) \cdot (x - x_2)$
#
# ---
#
# ### Vértice
#
# Se $a > 0$ a parábola tem concavidade p/ cima e um ponto mínimo $V$.
#
# Se $a < 0$ a parábola tem concavidade p/ baixo e um ponto máximo $V$.
#
# $V( -\frac{b}{2a} , -\frac{\Delta}{4a} )$
#
# <span style="color:red">Revisar, ver jeito mais intuitivo de achar do que decorar a fórmula</span>
#
# ---
#
# **Conjunto imagem**:
#
# Determinar o vértice $V$.
#
# Se $a > 0$ (concavidade p/ cima): $Im = \{ x \in \mathbb{R} | x \geq V \}$
#
# Se $a < 0$ (concavidade p/ baixo): $Im = \{ x \in \mathbb{R} | x \leq V \}$
#
# ---
#
# ### Esboço da Parábola
#
# Determinar:
# - A concavidade (sinal de $a$)
# - As raízes
# - O vértice
# - O eixo de simetria (reta $x = V_x$)
#
# ---

# %% [markdown]
# ### Exemplo
#
#
# Para $f(x) = 2x^2 - 5x + 2$:
#
# - $a = 2 > 0$, concavidade p/ cima
#
#
#
# - Vértice:
# $(-\frac{b}{a}, -\frac{\Delta}{a})$
#
# &nbsp; $\Rightarrow$ &nbsp; $(-\frac{-5}{2 \cdot 2}, -\frac{(-5)^2 - 4 \cdot 2 \cdot 2}{4 \cdot 2} )$
#
# &nbsp; $\Rightarrow$ &nbsp; $(\frac{5}{4}, -\frac{25-16}{8} )$
#
# &nbsp; $\Rightarrow$ &nbsp; $(\frac{5}{4}, -\frac{9}{8})$
#
#
# - Intersecção com eixo x:
#
# $f(0) = 2 \cdot 0^2 - 5 \cdot 0 + 2 = 2$ &nbsp; $\Rightarrow$ &nbsp; $(0, 2)$
#
#
# - Raízes:
#
# $x = \frac{-b \pm \sqrt{\Delta}}{2a}$
#
# &nbsp; $\Rightarrow$ &nbsp; $\frac{5 \pm \sqrt{9}}{4}$
#
# &nbsp; $\Rightarrow$ &nbsp; $x_1 = 2$, &nbsp; $x_2 = \frac{1}{2}$
#
# **Intersecções c/ y**: $(2, 0)$ e $(\frac{1}{2}, 0)$

# %%
xs = np.linspace(-1, 3.5)
ys = 2*(xs**2) - 5*xs + 2
points = [(2, 0), (1/2, 0), (0, 2), (5/4, -9/8)]

plotExample(xs, ys, points)

# %% [markdown]
# ---
#
# ### Estudo do sinal
#
# #### $\Delta \gt 0$
#
# Duas raízes reais.
#
# ![função](img/sinal_delta_gt0.jpg)
#
# #### $\Delta = 0$
#
# Uma raiz real.
#
# ![função](img/sinal_delta_0.jpg)
#
# #### $\Delta \lt 0$
#
# Não possui raízes reais.
#
# ![função](img/sinal_delta_lt0.jpg)
#
# ---
#
# **Inequações**: Colocar no formato $ax^2 + bx + c \geq 0$ (isolar um lado) e fazer o estudo de sinal.
#
# Ex: p/ resolver $x² - 2x < 150$, colocamos no formato $x^2 -x -150 < 0$ e obtemos a resposta pelo estudo do sinal do polinômio.

# %% [markdown]
# # 6 - Função definida por Várias Sentenças
#
# ## Gráfico
#
# Basta construir o gráfico correspondente para cada sentença e reuní-los.
#
# ---
#
# ## Módulo de um Número Real
#
# **Propriedades**:
#
# 1. $\forall x \in \mathbb{R}, |x| \geq 0$
#
# 2. $|x|^2 = x^2$
#
# 3. $|x| \leq a \Longleftrightarrow -a \leq x \leq a$
#
# 4. $|x| \geq a \Longleftrightarrow x \geq a$ &nbsp; ou &nbsp; $x \leq -a$
#
# ---
#
# ## Função Modular
#
# $$
# \begin{equation}
#   f(x) =
#     \begin{cases}
#       x, & \text{se $x \geq 0$}\\
#       -x, & \text{se $x \lt 0$}
#     \end{cases}
# \end{equation}
# $$
#
# ### Gráfico
#
# Basta traçar os gráficos de $f(x) = x$ (para $x \geq 0)$ e $f(x) = -x$ (para $x < 0$) e uní-los

# %%
xs = np.linspace(-4, 4)
ys = np.absolute(xs)

plotExample(xs, ys)

# %% [markdown]
# ### Exemplos
#
# $f(x) = |x| + 10$
#
# $$
# \begin{equation}
#   f(x) =
#     \begin{cases}
#       x + 10, & \text{se $x \geq 0$}\\
#       -x + 10, & \text{se $x \lt 0$}
#     \end{cases}
# \end{equation}
# $$
#
# ---
#
# $f(x) = |x + 2|$
#
# $$
# \begin{equation}
#   f(x) =
#     \begin{cases}
#       x + 2, & \text{se $x + 2\geq 0$ $\Rightarrow$ $x \geq -2$}\\
#       -x - 2, & \text{se $x + 2\lt 0$ $\Rightarrow$ $x \lt -2$}
#     \end{cases}
# \end{equation}
# $$
#
# ---
#
# $f(x) = |x + 2| + 10$
#
# $$
# \begin{equation}
#   f(x) =
#     \begin{cases}
#       x + 2 + 10 \Rightarrow x + 12, & \text{se $x + 2\geq 0$ $\Rightarrow$ $x \geq -2$}\\
#       -x - 2 + 10 \Rightarrow x + 8, & \text{se $x + 2\lt 0$ $\Rightarrow$ $x \lt -2$}
#     \end{cases}
# \end{equation}
# $$
#
# ---
#
# ## Inequações Modulares
#
# Aplica-se as propriedades 3 e 4.
#
# Exemplo:
#
# $| 2x - 3 | > 7 $
#
# $ \Longrightarrow 2x - 3 > 7 $ &nbsp; ou &nbsp; $ 2x - 3 < -7 $
#
# $ \Longrightarrow \{ x \in \mathbb{R} | x > 5 $ &nbsp; ou &nbsp; $ x  < -4 \}$

# %% [markdown]
# # 7 - Função Exponencial
#
#
# $a^x$, &nbsp; $a > 0$ &nbsp; e &nbsp; $a \neq 1$
#
# **Propriedades:**
#
# 1. $a^n \cdot a^m = a^{m+n}$
#
#
#
# 2. $\frac{a^m}{a^n} = a^{m-n}$ &nbsp;, para $ a \neq 0$
#
#
#
# 3. $(a \cdot b)^n = a^n \cdot b^n $
#
#
#
# 4. $(\frac{a}{b})^n = \frac{a^n}{b^n}$ &nbsp;, para $ b \neq 0$
#
#
#
# 5. $(a^m)^n = a^{m \cdot n}$
#
#
# **Potência de Expoente Inteiro Negativo**
#
# $a^{-n} = \frac{1}{a^n}$
#
# **Potência de Expoente Racional**
#
# $a^{\frac{1}{n}} =  \sqrt[n]{a}$
#
# **Potência de Expoente Irracional**
#
# Podemos aproximar utilizando valores menores e maiores.
#
# Por exemplo: $\sqrt{2} \simeq 1.41421356...$
#
# $2^{1.4142} = 2^{\frac{14142}{10000}} = \sqrt[10000]{2^{14142}} \simeq 2.6651$
#
# $2^{1.4143} \simeq 2.6653$
#
# ---
#
# ## Gráfico
#
# Para $f(x) = a^x$, podemos encontrar pontos no gráfico e ligá-los.
#
# A curva sempre corta o eixo Oy em $(0, 1)$
#
# Se $a \gt 1$ a curva é crescente.
#
# Se $0 < a < 1$ a curva é decrescente.
#
# A curva aproxima mas nunca cruza o eixo Ox.

# %%
xs = np.linspace(-4, 4)
ys1 = 2**xs
ys2 = (1/2)**xs

plotExample(xs, ys1, [(0,1)])
plotExample(xs, ys2, [(0,1)])

# %% [markdown]
# Gráficos de funções como $f(x) = a^x + b$ podem ser obtidos "deslocando" o gráfico de $a^x$ verticalmente $b$ unidades.
#
# Exemplo: $f(x) = 2^x + 3$
#
# - O gráfico cruzará o eixo Oy em $(0, 1+3) = (0, 4)$
#
# - A curva aproxima mas nunca toca a linha $y = 0 + 3 \Rightarrow y = 3$

# %%
xs = np.linspace(-4, 4)
ys1 = 2**xs + 3

plotExample(xs, ys1, [(0, 4)])

# %% [markdown]
# Gráficos de funções como $f(x) = k \cdot a^x$ se comportam da mesma forma que $f(x) = a^x$, porém cruzam o eixo Oy em $(0, k)$.
#
# $ k < 0 $ "inverte" a curva simetricamente em relação ao eixo Ox.
#
# Exemplos:
#
# - $f(x) = 3 \cdot 2^x $
#
# - $f(x) = -4 \cdot 2^x $

# %%
xs = np.linspace(-4, 2)
ys1 = 3 * 2**xs 
ys2 = -4 * 2**xs 

plotExample(xs, ys1, [(0, 3)])
plotExample(xs, ys2, [(0, -4)])

# %% [markdown]
# ---
#
# **Conjunto imagem:** $\forall x \in \mathbb{R}, a^x > 0$
#
# ---
#
# ## Equação Exponencial
#
# Um método para resolver consiste em reduzir ambos os membros da equação à uma potência de mesma base e então aplicar a propriedade: $a^{x_1} = a^{x_2} \Leftrightarrow x_1 = x_2$
#
# Exemplo:
#
# $(\frac{1}{3})^x = 81$ &nbsp; $\Rightarrow$ &nbsp; $3^{-x} = 3^{4}$ &nbsp; $\Rightarrow$ &nbsp; $x = -4$

# %% [markdown]
# # 8 - Função Logarítmica
#
# Logarítmo de **b** na base **a** é o exponente **x** ao qual se elevaria **a** para obter **b**.
#
# $\log_{a}{b} = x \Leftrightarrow a^x = b$
#
# * *a* é a **base**
# * *b* é o **logaritmando**
# * *x* é o **logaritmo**
#
#
# ## Consequências
#
# Sejam *a*, *b* e *c* números reais, $0 < a$ e $a \neq 1$, $b >0$ e $c > 0$
#
# 1. $\log_a{1} = 0$
# 2. $\log_a{a} = 1$
# 3. $a^{\log_a{b}} = b$
# 4. $\log_a{b} = \log_a{c} \Leftrightarrow b = c$
#
# ---
#
# **Sistemas de logaritmos**: Chamamos o conjunto de todos os logaritmos de base 2 dos números reais positivos de *sistema de logaritmos de base 2*
#
# **Sistema de logaritmos decimais**: $\log_{10}{x}$, comumente escrito apenas como $\log{x}$
#
# **Sistema de logarítmos neperianos**: $\log_{\mathrm{e}}{x}$, comumente escrito como $\ln{x}$ (logaritmo natural)
#
# ---
#
# ## Propriedades
#
# 1. $\log_a{(b \cdot c)} = \log_a{b} + \log_a{c}$
# 2. $\log_a{(\frac{b}{c})} = \log_a{b} - \log_a{c}$
# 3. $\log_a{b}^r = r \cdot \log_a{b}$
# 4. **Mudança de base:** $\log_a{c} = (\frac{\log_b{c}}{\log_b{a}})$
# 5. $\log_b{a} \cdot \log_a{b} = 1$
#
# ---
#
# ## Função Logarítmica
#
# $f(x) = log_a{x}$
#
# ### Gráfico
#
# * Inteiro contido nos 1o e 4o quadrantes, pois $f$ está definida apenas para $x > 0$
# * O conjunto imagem é $\mathbb{R}$
# * Cruza o eixo $Ox$ sempre em $(1, 0)$
# * Não cruza o eixo $Oy$
# * É sempre simétrica à função $f(x) = a^x$, o eixo de simetria sendo a reta $y = x$
#
# ---
#
# #### Exemplos
#
# $f(x) = \log_2{x}$

# %%
xs = np.linspace(0.1, 6)
ys = np.log2(xs)
plotExample(xs, ys, [(1, 0)])

# %%
xs1 = np.linspace(0.001, 9)
xs2 = np.linspace(-5, 3)
xs3 = np.linspace(-5, 9)

#log 1/3 x = (log10 x) / (log10 1/3)
ys1 = np.log2(xs1)
ys2 = 2**xs2
ys3 = xs3

plt.plot(xs1, ys1, linestyle='-')
plt.plot(xs2, ys2, linestyle='-')
plt.plot(xs3, ys3, linestyle='--')
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.axis('scaled')
plt.show()

# %% [markdown]
# ---
#
# $f(x) = \log_{\frac{1}{3}}{x}$

# %%
xs1 = np.linspace(0.001, 4)
xs2 = np.linspace(-1, 4)

#log 1/3 x = (log10 x) / (log10 1/3)
ys1 = np.log10(xs1) / np.log10(1/3)
ys2 = (1/3)**xs2
ys3 = xs2

plt.plot(xs1, ys1, linestyle='-')
plt.plot(xs2, ys2, linestyle='-')
plt.plot(xs2, ys3, linestyle='--')
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.text(3, np.log10(3)/np.log10(1/3), 'log(1/3) x')
plt.text(-1, (1/3)**(-1), 'x^(1/3)')
plt.axis('scaled')
plt.show()

# %% [markdown]
# ## Equações Exponenciais
#
# **Quando não podem ser reduzidas a potências de mesma base**, utiliza-se o logaritmo.
#
# $3^x = 5 \Rightarrow x = log_3{5}  = \frac{log{5}}{log{3}}$
#
# Podemos "aplicar" ele dos dois lados, exemplo:
#
# $3^x = 5 \Rightarrow log{3^x} = log{5} \Rightarrow x \cdot log{3} = log{5}$
#
# ---

# %% [markdown]
# # 9 - Progressões
#
# **Termo geral**: lei de formação (fórmula) de uma sequência.
#
# **Lei de recorrência**: lei de formação de uma sequência dada recursivamente (elemento é definido baseado em elementos anteriores).
#
# ## Progressões Aritméticas (P.A.)
#
# Sequência onde cada termo após o 1o é obtido somando-se uma constante $r$, $r$ é chamada de **razão da P.A.**.
#
# **Termo geral:** $a_n = a_1 + (n-1) \cdot r$  (pega o primeiro e soma-se n-1 vezes a razão)
#
# **Soma dos primeiros n termos:** $S_n = \frac{(a_1 + a_n) \cdot n}{2}$
#
#
# Observação: a lei de formação da P.A. é uma função afim $f(x) = a_1 + (x-1) \cdot r \Rightarrow rx + (a_1 - r)$
#
# ---
#
# ## Progressões Geométricas (P.G.)
#
# Sequência onde cada termo após o 1o é obtido multiplicando-se uma constante $q$ (**razão da P.G.**)
#
# **Termo geral:** $a_n = a_1 \cdot q^{n-1}$
#
# ---
#
# * **Crescente**: $a_1 > 0$ &nbsp; e &nbsp;  $q > 0$ &nbsp; &nbsp; &nbsp; ou &nbsp; &nbsp; &nbsp; $a_1 < 0$ &nbsp; e &nbsp; $0 < q < 1$
#
# * **Derescente**: $a_1 > 0$ &nbsp; e &nbsp;  $0 < q < 1$ &nbsp; &nbsp; &nbsp; ou &nbsp; &nbsp; &nbsp; $a_1 < 0$ &nbsp; e &nbsp; $q > 1$
#
# * **Constante**: $q = 1$ ou $a_1 = 0$
#
# * **Alternada ou oscilante**: $q < 0$
#
# * **Estacionária**: constante a partir do 2o termo, $q = 0$ e $a \neq 0$
#
# ---
#
# ### Soma dos primeiros termos
#
# $S_n = a_1 + a_2 + a_3 + ... + a_n$ &nbsp; &nbsp; &nbsp; *(1)*
#
# __
#
# $q \cdot S_n = q \cdot (a_1 + a_2 + a_3 + ... + a_n)$
#
# &nbsp; $\Rightarrow q \cdot S_n = a_2 + a_3 + a_4 + ... + a_n + (q \cdot a_n)$ &nbsp; &nbsp; &nbsp; *(2)*
#
# __
#
# $(q-1) \cdot S_n = a_1 + (q \cdot a_n)$ &nbsp; &nbsp; &nbsp; *(2-1) (3)*
#
# &nbsp; $\Rightarrow S_n = \frac{(q \cdot a_n) - a_1}{q-1}$
#
# __
#
# Como $a_n = a_1 \cdot q^{n-1}$:
#
# $S_n = \frac{(q \cdot (a_1 \cdot q^{n-1})) - a_1}{q-1} = \frac{a_1 \cdot (q^{n} - 1)}{q -1}$
#
# ---
#
# ### Soma dos termos de uma P.G. infinita
#
# Em uma sequência como $a_n = (\frac{1}{10})^n$, $a_n$ tende a $0$ quanto $n$ tende ao infinito.
#
# Utilizando a fórmula (3) acima, podemos considerar que para infinitos números, $a_1 = 1$ e $a_n = 0$.
#
# $S_n = \frac{(\frac{1}{10} \cdot 0) - 1}{\frac{1}{10}-1} = \frac{-1}{-\frac{9}{10}} = \frac{10}{9} = 1.111$
#
# No geral, $S_{n_{inf}} = \frac{a_1}{1-q}$
#
# ---
#
# Observação: O termo geral da P.G. é uma função exponencial.

# %% [markdown]
# # 10 - Semelhança de Triângulos Retângulos
#
# Dois triângulos são semelhantes se seus ângulos correspondentes são congruentes e lados homólogos são proporcionais.
#
# ## Teorema de Tales
#
# Se duas retas são transversais a um feixe de retas paralelas, então a razão entre as medidas dos segmentes quaisquer de uma é igual à razão entre as medidas dos segmentos correspondentes da outra.
#
# ![Teorema de Tales](img/tales.jpg)
#
# Na figura, $\frac{AB}{A'B'} = \frac{CD}{C'D'} = k$ ($k$ é a **razão de semelhança**)
#
# ---
#
# ## Teorema fundamental da semelhança
#
# Toda reta paralela a um lado de um triângulo, que intersecta os outros dois lados em pontos distintos, determina um novo triângulo semelhante ao 1o.
#
# ![Teorema de Fundamental da Semelhança](img/semelhanca_triangulo.jpg)
#
# ---
#
# ## Critérios de Semelhança
#
# * Dois ângulos iguais (ângulo - ângulo)
# * Dois lados proporcionais + mesmo ângulo entre eles (lado - ângulo - lado)
# * Três lados proporcionais (lado - lado - lado)
#
# ---
#
# ## Consequências
#
# Se a razão de semelhança entre dois triângulos é **k**, então:
#
# * a razão entre duas **alturas** homólogas é **k**
# * a razão entre duas **medianas** (ponto médio do lado - vértice oposto) homólogas é **k**
# * a razão entre duas **bissetrizes** (reta que divide um ângulo em 2) homólogas é **k**
# * a razão entre as **áreas** é **k²**
#
# * Se ligarmos dois pontos médios, a medida é 1/2 do outro lado (base do triangulinho semelhante).
#
# ---
#
# ## Triângulo retângulo
#
# Ao traçar a altura relativa à hipotenusa, dividimos um triângulo retângulo em 2 triângulos semelhantes (ao original).
#
#
# ![Triângulo retângulo](img/triangulo_retangulo.jpg)
#
# $\frac{a}{c} = \frac{c}{n} \Rightarrow c^2 = a \cdot n$
#
#
# $\frac{a}{b} = \frac{b}{m} \Rightarrow b^2 = a \cdot m$
#
#
# $\frac{a}{m} = \frac{n}{h} \Rightarrow h^2 = m \cdot n$
#
# $b \cdot c = a \cdot h$
#
#
# **Teorema de Pitágoras:** $a^2 = b^2 + c^2$
#
# ---

# %% [markdown]
# # 11 - Trigonometria no triângulo retângulo
#
# ## Razões trigonométricas
#
# $sen \theta = \frac{\text{cateto oposto}}{\text{hipotenusa}}$
#
# $cos \theta = \frac{\text{cateto adjacente}}{\text{hipotenusa}}$
#
# $tg \theta = \frac{\text{cateto oposto}}{\text{cateto adjacente}} = \frac{sen\theta}{cos\theta}$
#
#
# ## Ângulos Notáveis
#
# ![Triângulo retângulo](img/trig_triangulo_ret.jpg)

# %% [markdown]
# ### 30°
#
# $sen 30° = \frac{\frac{L}{2}}{L} = \frac{1}{2}$
#
# $cos 30° = \frac{\frac{L\sqrt{3}}{2}}{L} = \frac{\sqrt{3}}{2}$
#
# $tg 30° = \frac{\frac{1}{2}}{\frac{\sqrt{3}}{2}} = \frac{1}{\sqrt{3}} = \frac{\sqrt{3}}{3}$
#
#
# ### 60°
#
# $sen 60° = \frac{\frac{L\sqrt{3}}{2}}{L} = \frac{\sqrt{3}}{2}$
#
# $cos 60° = \frac{\frac{L}{2}}{L} = \frac{1}{2}$
#
# $tg 60°  = \frac{\frac{\sqrt{3}}{2}}{\frac{1}{2}} = \sqrt{3}$
#
# ---
#
# ![Quadrado](img/trig_quad.jpg)

# %% [markdown]
# ### 45°
#
# $sen 45° = \frac{L}{L\sqrt{2}} = \frac{1}{\sqrt{2}} = \frac{\sqrt{2}}{2}$
#
# $cos 45° = \frac{L}{L\sqrt{2}} = \frac{\sqrt{2}}{2}$
#
# $tg 45°  = \frac{L}{L} = 1$
#
# ---

# %% [markdown]
# # 12 - Áreas de Figuras Planas
#
# **Retângulo:** $A = b \cdot h$
#
#
# **Quadrado:** $A = l^2$
#
# **Parelogramo:** Pode-se "deslocar" a sobra para o outro lado, virando um retângulo, $A = b \cdot h$
#
# ![Paralelogramo](img/paralelogramo.jpg)
#
# **Triângulo:** $A = \frac{b \cdot h}{2}$
#
# **Losango**: Se "completarmos" o lado, ficamos com um retângulo de área $d \cdot D$ que é o dobro da áre que queremos, logo: $A = \frac{D \cdot d}{2}$
#
# ![Losango](img/losango.jpg)
#
# **Trapézio**: Área do retângulo interno + 2x área do triângulo (pontas) $\Rightarrow$ $(b \cdot h) + 2(\frac{(B-b)}{2} \cdot h)/2$ $\Rightarrow$ $(b \cdot h) + \frac{(B \cdot h)}{2} - \frac{(b \cdot h)}{2}$ $\Rightarrow$ $A = \frac{(B+b) \cdot h}{2}$
#
# ---
#
# ## Área de um Polígono Regular
#
# ![Hexágono Regular](img/hexagono_regular.jpg)
#
# **a** é o apótema (segmento perpendicular ao lado, liga ponto médio do lado ao ponto médio do polígono)
#
# Sendo **2p** o perímetro (soma dos lados $= n \cdot L$),
#
# Temos que a área é $n$ vezes a medida do triângulo cuja área é $\frac{L \cdot a}{2}$
#
# $A = n \cdot \frac{L \cdot a}{2} = p \cdot a$
#
# ---
#
# ## Área do Círculo e Suas Partes
#
# $A = \pi r^2$
#
# $2p = 2 \pi r$
#
# A **área do setor circular** é proporcional ao círculo. Ex, p/ um setor de ângulo $\alpha$: $\frac{A_{setor}}{\pi r^2} = \frac{\alpha}{360}$
#
# O mesmo vale para a **medida do arco** do setor circular.
#
# A **área da coroa circular** (donut) é a área do círculo maior - a do menor.
#
# A **área de um segmento circular** é obtida pela *área do setor circular* - *área do triângulo* (formado ao ligar o setor ao centro.
#
# ![Setor Circular](img/setor_circular.jpg)
#
# ---

# %% [markdown]
# # 13 - Estatística Básica
#
# **Universo estatístico** ou **população**: conjunto total de pessoas/elementos que podem oferecer as informações que serão investigadas.
#
# **Amostra**: parcela da população da qual se coleta os dados.
#
# ---
#
# ## Etapas da Pesquisa Estatística
#
# 1. **Planejamento**: definição dos objetivos, tipo de pesquisa, população, como a amostra será obtida
# 2. **Coleta de dados**
# 3. **Apuração ou contagem dos dados**: Organização/agrupamento dos dados
# 4. **Exposição**: Apresentação dos dados (tabelas, gráficos).
# 5. **Interpretação**: Interpretação dos dados, **inferência estatística**.
#
# **Amostragem aleatória ou simples**: seleciona-se elementos da população com a mesma probabilidade.
# **Amostragem proporcional estratificada**: divide-se a população em estratos, selecionando amostras proporcionalmente entre eles
#
# Variáveis podem ser **quantiativas** (medidas) ou **qualitativas** (opções).
#
# **Frequência relativa**: $F_r = \frac{\text{Frequência de um valor}}{\text{número total de dados}}$
#
# Quando a amplitude de um dado é muito alta podemos definir **classes** ou **intervalos de valores**.
#
# ---
#
# ## Representações Gráficas
#
# ### Gráfico de Barras
#
# ![Gráfico de Barras](img/grafico_barras.jpg)
#
# ### Histograma
#
# ![Histograma](img/histograma.jpg)
#
# ### Gráfico de Setores
#
# ![Gráfico de Setores](img/grafico_setores.jpg)
#
# ### Gráfico de Linhas
#
# ![Gráfico de Linhas](img/grafico_linhas.jpg)
#
# ### Pictograma
#
# ![Pictograma](img/pictograma.jpg)
